# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/kaggle/input/digit-recognizer/train.csv')
df.head()

# %%
df.shape

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(df.iloc[18306,1:].values.reshape(28,28))

# %%
X=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=45)

# %%
X_train.shape,X_test.shape

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(X_train,y_train)

# %%
import time 
start=time.time()
y_pred=knn.predict(X_test)
print(time.time()-start)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)

# %%
# before doing pca 
# first we standardsize our data
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
# using pca
from sklearn.decomposition import PCA
pca=PCA(n_components=50)

# %%
X_train_trf=pca.fit_transform(X_train)
X_test_trf=pca.transform(X_test)

# %%
X_train.shape,X_train_trf.shape

# %%
# now will train this data again
knn=KNeighborsClassifier()

# %%
knn.fit(X_train_trf,y_train)

# %%
y_predd=knn.predict(X_test_trf)

# %%
accuracy_score(y_test,y_pred)

# %%
for i in range(1,785):
    pca=PCA(n_components=i)
    X_train_trf=pca.fit_transform(X_train)
    X_test_trf=pca.transform(X_test)
    
    knn=KNeighborsClassifier()
    
    knn.fit(X_train_trf,y_train)

    y_predd=knn.predict(X_test_trf)
    
    print(accuracy_score(y_test,y_predd))
# Out:
# 0.26031746031746034
# 0.33015873015873015
# 0.5058730158730159
# 0.6619047619047619
# 0.7293650793650793
# 0.8225396825396826
# 0.8385714285714285
# 0.868968253968254
# 0.8811111111111111
# 0.9041269841269841
# 0.9094444444444445
# 0.9153174603174603
# 0.9253174603174603
# 0.9303968253968254
# 0.9334920634920635
# 0.9346825396825397
# 0.936984126984127
# 0.9384126984126984
# 0.9399206349206349
# 0.9423015873015873
# 0.9421428571428572
# 0.9426190476190476
# 0.9414285714285714
# 0.943968253968254
# 0.9453174603174603
# 0.9462698412698413
# 0.9473015873015873
# 0.9462698412698413
# 0.9480952380952381
# 0.9476190476190476
# 0.948015873015873
# 0.9477777777777778
# 0.9487301587301588
# 0.9491269841269842
# 0.9513492063492064
# 0.9520634920634921
# 0.9517460317460318
# 0.9514285714285714
# 0.9513492063492064
# 0.9512698412698413
# 0.9518253968253968
# 0.9519047619047619
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[98], line 10
#       6 knn=KNeighborsClassifier()
#       8 knn.fit(X_train_trf,y_train)
# ---> 10 y_predd=knn.predict(X_test_trf)
#      12 print(accuracy_score(y_test,y_predd))
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/neighbors/_classification.py:252, in KNeighborsClassifier.predict(self, X)
#     250 for k, classes_k in enumerate(classes_):
#     251     if weights is None:
# --> 252         mode, _ = _mode(_y[neigh_ind, k], axis=1)
#     253     else:
#     254         mode, _ = weighted_mode(_y[neigh_ind, k], weights, axis=1)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/fixes.py:169, in _mode(a, axis)
#     167 def _mode(a, axis=0):
#     168     if sp_version >= parse_version("1.9.0"):
# --> 169         mode = scipy.stats.mode(a, axis=axis, keepdims=True)
#     170         if sp_version >= parse_version("1.10.999"):
#     171             # scipy.stats.mode has changed returned array shape with axis=None
#     172             # and keepdims=True, see https://github.com/scipy/scipy/pull/17561
#     173             if axis is None:
#
# File /opt/conda/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:591, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     588         return result_to_tuple(hypotest_fun_out(*samples, **kwds))
#     590 x = np.moveaxis(x, axis, 0)
# --> 591 res = np.apply_along_axis(hypotest_fun, axis=0, arr=x)
#     592 res = _add_reduced_axes(res, reduced_axes, keepdims)
#     593 return tuple_to_result(*res)
#
# File <__array_function__ internals>:180, in apply_along_axis(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/numpy/lib/shape_base.py:402, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     400 buff[ind0] = res
#     401 for ind in inds:
# --> 402     buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     404 if not isinstance(res, matrix):
#     405     # wrap the array, to preserve subclasses
#     406     buff = res.__array_wrap__(buff)
#
# File /opt/conda/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:588, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper.<locals>.hypotest_fun(x)
#     586 if is_too_small(samples):
#     587     return np.full(n_out, np.nan)
# --> 588 return result_to_tuple(hypotest_fun_out(*samples, **kwds))
#
# File /opt/conda/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:373, in _axis_nan_policy_factory.<locals>.result_to_tuple(res)
#     370 override.update(temp)
#     372 if result_to_tuple is None:
# --> 373     def result_to_tuple(res):
#     374         return res
#     376 def is_too_small(samples):
#
# KeyboardInterrupt:
